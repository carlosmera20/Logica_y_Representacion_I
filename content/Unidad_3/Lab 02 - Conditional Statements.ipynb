# %% [markdown]
# <img src="https://raw.githubusercontent.com/carlosmera20/Logica_y_Representacion_I/main/content/local/imgs/encabezado.png">
#
# <font size=4>
# 📢 <b>Profesor:</b> Carlos Andres Mera Banguero - <a href="https://github.com/carlosmera20/">https://github.com/carlosmera20/</a><br/>
# 💻 <b>Programa:</b> Ingeniería de Sistemas <br/><br/>
# </font>

# %% [markdown]
# # 🐍 <b>LAB 02 - Conditional Statements</b>

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/carlosmera20/Logica_y_Representacion_I/main/content/init.py
import init; init.init(force_download=False); init.get_weblink()

# %%
import inspect
from local.lib.rlxmoocapi import session
session.LoginSequence(endpoint=init.endpoint, course_id=init.course_id, lab_id="LR01.02", varname="student");

# %% [markdown]
# # 🚊 **Exercise 1:**
#
# Complete the following function to indicate whether a given character is a number (returning 1), a lowercase letter (returning 2), an uppercase letter (returning 3), or a symbol (returning -1).
#
# **Clue:** use characthers' ASCII numbers which can be obtained using the <a href="https://www.w3schools.com/python/ref_func_ord.asp">`ord()`</a> function.
#
# **Example**
#
# ````
# Input : "2"
# Output :  1
#
# Input : "F"
# Output : 3
#
# Input : "#"
# Output : -1
# ````

# %%
def get_type_of_character(char):
    ## --- YOUR CODE HERE ---
    return 0

# %% [markdown]
# Test your code in the following cell.

# %%
# Test your code here
print(get_type_of_character("x")) # Shlould print 2

print(get_type_of_character("7")) # Shlould print 1

print(get_type_of_character("%")) # Shlould print -1

print(get_type_of_character("H")) # Shlould print 3

# %% [markdown]
# ### **Send your answer here**
# Run the following cell to submit your task

# %%
student.submit_task(namespace=globals(), task_id='T1');

# %% [markdown]
# # 🚊 **Exercise 2**:
#
# Create a class named Circle that corresponds with the given diagram. That class has three attributes: the radio and the x and y coordinates in the Cartesian plane. Also, the class has three methods: one to calculate the area, the other to calculate the perimeter, and one more to determine if the Circle overlaps the other Circle, which is given as a parameter.
#
# <center> <img src="https://raw.githubusercontent.com/carlosmera20/Logica_y_Representacion_I/main/content/local/imgs/Circle_class.png"></center>

# %%
def get_class():

    class Circle:
        pass

        ## --- YOUR CODE HERE ---

    return Circle

# %% [markdown]
# Test your code with two circle C1 and C2.

# %%
# Testing your class with two circles
Circle = get_class()
c1 = Circle(0, 0, 5)
c2 = Circle(0, 3, 3)

print (f"C1 area: {c1.calculate_area()}")
print (f"C1 perimeter: {c1.calculate_perimeter()}")
print (f"Is c1 overlapping with c2? - {c1.is_overlapping_with(c2)}")

# %% [markdown]
# ### **Send your answer here**
# Run the following cell to submit your task

# %%
student.submit_task(namespace=globals(), task_id='T2');

# %% [markdown]
# # 🚊 **Exercise 3:**
# Implement a function that, given the three sides of a triangle, indicates whether it is equilateral, isosceles or scalene. However, if the triangle is scalene and also rectangle, it must return scalene-rectangle.

# %%
def get_triangle_type(a, b, c):

    ## --- YOUR CODE HERE ---

    return None

# %% [markdown]
# Test your code. For example, using the values a=2, b=2, and c=2 the function must return equilateral, but with the values a=2, b=4, and c=2 the function must return isosceles, while witht the values a=1, b=2 and c=3 the function must return scalene. Finally, with a=5, b=3 and c=4 the function must return scalene-rectangle.

# %%
print(get_triangle_type(a=2, b=2, c=2)) # Should print equilateral

print(get_triangle_type(a=2, b=4, c=2)) # Should print isosceles

print(get_triangle_type(a=1, b=2, c=3)) # Should print scalene

print(get_triangle_type(a=5, b=3, c=4)) # Should print scalene

# %% [markdown]
# ### **Send your answer here**
# Run the following cell to submit your task

# %%
student.submit_task(namespace=globals(), task_id='T3');

# %% [markdown]
# # 🚊 **Exercise 4:**
# Create a class named Person that corresponds with the given diagram. That class has three attributes: the Person's name, their salary, and a password to access the salary. Also, the class has three methods: the constructor method, which has to receive all Person data to create an object, one to establish a new password, and the other to get the salary.
#
# - The method set_password receives the new password and returns an integer, which is 0 if the change password was successful, 1 if the password does not meet the required length (between 8 and 16 characters), and 2 if it does not have one of the following special characters: $, #, @, %, *.
# - The method get_salary returns the Person's salary when the parameter password matches the real Person's password; otherwise, it returns -1.
# <center> <img src="https://raw.githubusercontent.com/carlosmera20/Logica_y_Representacion_I/main/content/local/imgs/Person_class.png"></center>

# %%
def get_class_person():

    class Person:
        pass

        ## --- YOUR CODE HERE ---

    return Person

# %% [markdown]
# Test your code in the following cell

# %%
# Instantiate, an object from the class Person
Person = get_class_person()
p = Person("Carlos", 3300,"pass$1234")

print(p.set_password("hola")) # It should print 1
print(p.set_password("hola12345")) # It should print 2
print(p.set_password("hola#12345")) # It should print 0

print(p.get_salary("pass$1234")) # It should print -1
print(p.get_salary("hola#12345")) # It should print 3300

# %% [markdown]
# ### **Send your answer here**
# Run the following cell to submit your task

# %%
student.submit_task(namespace=globals(), task_id='T4');
